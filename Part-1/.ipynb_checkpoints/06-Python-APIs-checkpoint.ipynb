# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import sys
sys.path.insert(0, 'C:/Users/Aaron/Documents')

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import gmaps

now = datetime.datetime.now()

# Import API key
from config import OW_api_key as key
from config import Gmaps_api_key as gkey
gmaps.configure(api_key=gkey)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
lat_lng_map = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        lat_lng_map.append(lat_lng)
# Print the city count to confirm sufficient count

len(cities)
# Out:
# 604

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'}


cities_layer = gmaps.symbol_layer(
    lat_lng_map, fill_color='green', stroke_color='green', scale=2)
fig = gmaps.figure(center=(0,0), zoom_level=1)
fig.add_layer(cities_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={key}&units={units}&q="

# set up lists to hold reponse info
lat = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
city_name = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()

    try:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response['name'])
        
        print(f"Processing record {cities.index(city)} for {city} with temp {temp[-1]}")
        
    except KeyError:
        print("Missing field/result, skipping")
# Out:
# Processing record 0 for tiznit with temp 54.32
# Processing record 1 for methoni with temp 63.82
# Processing record 2 for pisco with temp 67.96
# Processing record 3 for hovd with temp 46.04
# Processing record 4 for bandarbeyla with temp 80.71
# Processing record 5 for bethel with temp 34.7
# Processing record 6 for constitucion with temp 77.38
# Processing record 7 for hermanus with temp 55.54
# Processing record 8 for bluff with temp 75.88
# Processing record 9 for preobrazheniye with temp 51.71
# Processing record 10 for port elizabeth with temp 60.01
# Processing record 11 for bara with temp 75.88
# Processing record 12 for jamestown with temp 65.98
# Processing record 13 for marrakesh with temp 57.2
# Processing record 14 for dudinka with temp 24.8
# Processing record 15 for port blair with temp 77
# Processing record 16 for ushuaia with temp 57.2
# Processing record 17 for clyde river with temp 30.2
# Processing record 18 for rikitea with temp 70.38
# Processing record 19 for qingdao with temp 51.8
# Processing record 20 for mpulungu with temp 68.56
# Processing record 21 for lulea with temp 33.8
# Processing record 22 for sisimiut with temp 25.41
# Processing record 23 for new norfolk with temp 59.85
# Processing record 24 for barrow with temp 46.02
# Processing record 25 for hilo with temp 81.03
# Processing record 26 for castro with temp 60.8
# Processing record 27 for nikolskoye with temp 47.53
# Processing record 28 for santa cruz del sur with temp 85.44
# Processing record 29 for salinopolis with temp 82.17
# Processing record 30 for paamiut with temp 37.83
# Processing record 31 for hobart with temp 59.99
# Processing record 32 for vega de alatorre with temp 79.77
# Processing record 33 for divnoye with temp 51.49
# Processing record 34 for lebu with temp 46.31
# Processing record 35 for katsuura with temp 66.07
# Processing record 36 for bambous virieux with temp 71.82
# Processing record 37 for victoria with temp 75.13
# Processing record 38 for bull savanna with temp 72.63
# Missing field/result, skipping
# Missing field/result, skipping
# Processing record 41 for camacha with temp 65.43
# Processing record 42 for touros with temp 77
# Processing record 43 for punta arenas with temp 55.17
# Processing record 44 for chokurdakh with temp 0.37
# Processing record 45 for mount isa with temp 78.8
# Processing record 46 for yellowknife with temp 29.7
# Processing record 47 for mataura with temp 48
# Processing record 48 for yar-sale with temp 20.64
# Processing record 49 for temba with temp 70
# Processing record 50 for waipawa with temp 55.99
# Processing record 51 for vanavara with temp 22.21
# Missing field/result, skipping
# Processing record 53 for butaritari with temp 84.94
# Processing record 54 for kavieng with temp 84.63
# Processing record 55 for busselton with temp 48.61
# Missing field/result, skipping
# Processing record 57 for nanortalik with temp 34.29
# Processing record 58 for fortuna with temp 70.59
# Processing record 59 for ponta delgada with temp 69.91
# Processing record 60 for ribeira grande with temp 66.92
# Processing record 61 for khatanga with temp 3.02
# Processing record 62 for geraldton with temp 35.6
# Processing record 63 for lompoc with temp 80.98
# Processing record 64 for makakilo city with temp 84.96
# Processing record 65 for vaini with temp 69.4
# Processing record 66 for pevek with temp 19.36
# Missing field/result, skipping
# Processing record 68 for alofi with temp 77
# Processing record 69 for kholmskaya with temp 46.54
# Processing record 70 for broome with temp 53.49
# Processing record 71 for bowen with temp 78.57
# Processing record 72 for cherskiy with temp 6.58
# Processing record 73 for sorland with temp 43.14
# Processing record 74 for laguna with temp 84.2
# Processing record 75 for yulara with temp 75.2
# Processing record 76 for bonthe with temp 78.58
# Processing record 77 for cape town with temp 57.65
# Missing field/result, skipping
# Processing record 79 for barra patuca with temp 84.33
# Processing record 80 for husavik with temp 36.91
# Processing record 81 for whitianga with temp 61
# Processing record 82 for hithadhoo with temp 77.99
# Processing record 83 for atuona with temp 78.94
# Processing record 84 for creel with temp 61.07
# Processing record 85 for plettenberg bay with temp 57.76
# Processing record 86 for maryborough with temp 78.64
# Processing record 87 for atbasar with temp 40.01
# Processing record 88 for sabang with temp 75.99
# Processing record 89 for thompson with temp 33.8
# Processing record 90 for solone with temp 49.15
# Processing record 91 for yarmouth with temp 54.55
# Processing record 92 for port hedland with temp 69.8
# Processing record 93 for provideniya with temp 32
# Processing record 94 for sao filipe with temp 73.76
# Processing record 95 for serik with temp 68
# Processing record 96 for verkhnevilyuysk with temp 18.01
# Processing record 97 for klaksvik with temp 42.8
# Processing record 98 for jinchang with temp 25.65
# Missing field/result, skipping
# Processing record 100 for gat with temp 79.54
# Processing record 101 for port alfred with temp 60.01
# Processing record 102 for saint-philippe with temp 53.8
# Processing record 103 for kodiak with temp 61.16
# Processing record 104 for valleyview with temp 35.29
# Processing record 105 for iquitos with temp 82.4
# Missing field/result, skipping
# Processing record 107 for turukhansk with temp 27.55
# Missing field/result, skipping
# Processing record 109 for coihaique with temp 68
# Processing record 110 for luderitz with temp 57.2
# Processing record 111 for carutapera with temp 82.22
# Missing field/result, skipping
# Processing record 113 for colwyn bay with temp 49.28
# Processing record 114 for saint george with temp 56.35
# Processing record 115 for koumac with temp 76.44
# Processing record 116 for tinde with temp 72.79
# Processing record 117 for ust-tsilma with temp 27.25
# Missing field/result, skipping
# Processing record 119 for tuatapere with temp 48
# Processing record 120 for sawakin with temp 86.76
# Processing record 121 for huarmey with temp 62.92
# Processing record 122 for georgetown with temp 83.25
# Processing record 123 for omboue with temp 73.83
# Processing record 124 for veraval with temp 53.65
# Processing record 125 for matagami with temp 68
# Processing record 126 for fredericton with temp 53.38
# Processing record 127 for east london with temp 63.36
# Processing record 128 for dikson with temp 17.06
# Processing record 129 for esperance with temp 51.8
# Processing record 130 for monrovia with temp 77
# Processing record 131 for longyearbyen with temp 21.2
# Missing field/result, skipping
# Processing record 133 for airai with temp 78.87
# Processing record 134 for albany with temp 53.49
# Processing record 135 for souillac with temp 56.1
# Processing record 136 for askino with temp 42.73
# Processing record 137 for severo-kurilsk with temp 42.82
# Processing record 138 for bow island with temp 39.04
# Processing record 139 for voh with temp 70.97
# Processing record 140 for derzhavinsk with temp 42.85
# Processing record 141 for lazaro cardenas with temp 80.6
# Processing record 142 for yurimaguas with temp 71.6
# Processing record 143 for channel-port aux basques with temp 47.95
# Processing record 144 for mar del plata with temp 49.01
# Processing record 145 for portland with temp 54.91
# Processing record 146 for tahe with temp 27.25
# Missing field/result, skipping
# Processing record 148 for kapaa with temp 82.56
# Processing record 149 for marzuq with temp 65.52
# Processing record 150 for bredasdorp with temp 55.9
# Processing record 151 for tromso with temp 31.06
# Processing record 152 for havre-saint-pierre with temp 42.8
# Processing record 153 for arraial do cabo with temp 73.4
# Processing record 154 for vila velha with temp 80.6
# Processing record 155 for gamba with temp 25.48
# Processing record 156 for kaitangata with temp 46.44
# Processing record 157 for impfondo with temp 69.85
# Processing record 158 for carnarvon with temp 53.19
# Processing record 159 for mehamn with temp 30.2
# Processing record 160 for chapais with temp 44.6
# Processing record 161 for ilulissat with temp 21.2
# Processing record 162 for cervo with temp 62.49
# Processing record 163 for tasiilaq with temp 26.6
# Processing record 164 for polson with temp 49.39
# Processing record 165 for saint-pierre with temp 55.02
# Missing field/result, skipping
# Processing record 167 for moindou with temp 73.4
# Processing record 168 for mecca with temp 79.45
# Processing record 169 for kenai with temp 49.24
# Processing record 170 for gold coast with temp 73.04
# Processing record 171 for las palmas with temp 76.77
# Processing record 172 for poum with temp 50.32
# Missing field/result, skipping
# Processing record 174 for ust-nera with temp -6.94
# Processing record 175 for dalby with temp 70.83
# Processing record 176 for cayenne with temp 82.4
# Processing record 177 for codrington with temp 68.63
# Processing record 178 for mosjoen with temp 48.07
# Processing record 179 for niksar with temp 49.05
# Processing record 180 for qaanaaq with temp 22.82
# Processing record 181 for salalah with temp 78.8
# Processing record 182 for dingle with temp 80.83
# Processing record 183 for praia with temp 77
# Processing record 184 for torbay with temp 44.65
# Processing record 185 for tigil with temp 21.94
# Processing record 186 for karratha with temp 80.98
# Processing record 187 for grindavik with temp 26.02
# Processing record 188 for kirakira with temp 82.76
# Missing field/result, skipping
# Processing record 190 for chumphon with temp 75.74
# Processing record 191 for beringovskiy with temp 21.97
# Processing record 192 for mogok with temp 65.01
# Processing record 193 for vostok with temp 44.47
# Processing record 194 for guerrero negro with temp 79.86
# Processing record 195 for naze with temp 80.6
# Processing record 196 for levokumskoye with temp 48.27
# Processing record 197 for freeport with temp 80.6
# Processing record 198 for nome with temp 73.65
# Missing field/result, skipping
# Missing field/result, skipping
# Processing record 201 for osypenko with temp 48.2
# Missing field/result, skipping
# Processing record 203 for columbus with temp 68.86
# Processing record 204 for norman wells with temp 24.8
# Processing record 205 for faanui with temp 79.68
# Processing record 206 for araouane with temp 89.74
# Processing record 207 for upernavik with temp 21.88
# Processing record 208 for pacaembu with temp 78.15
# Processing record 209 for saldanha with temp 45.59
# Processing record 210 for coos bay with temp 64.09
# Processing record 211 for tual with temp 81.05
# Processing record 212 for marawi with temp 78.01
# Missing field/result, skipping
# Processing record 214 for bologoye with temp 46.89
# Processing record 215 for avarua with temp 77
# Processing record 216 for khromtau with temp 42.71
# Processing record 217 for roald with temp 50.23
# Processing record 218 for acapulco with temp 86
# Processing record 219 for florianopolis with temp 65.66
# Processing record 220 for gushikawa with temp 73.85
# Processing record 221 for zhezkazgan with temp 35.65
# Processing record 222 for bubaque with temp 82.78
# Processing record 223 for tuktoyaktuk with temp 17.6
# Processing record 224 for puerto ayora with temp 72.21
# Processing record 225 for san patricio with temp 64.92
# Processing record 226 for alta floresta with temp 77
# Processing record 227 for piedras negras with temp 85.17
# Processing record 228 for chiredzi with temp 73.53
# Processing record 229 for sergeyevka with temp 37.02
# Processing record 230 for rawa mazowiecka with temp 52.61
# Processing record 231 for kabo with temp 71.17
# Processing record 232 for bhimunipatnam with temp 75.2
# Processing record 233 for tautira with temp 84.07
# Processing record 234 for nouadhibou with temp 69.8
# Processing record 235 for harper with temp 79.74
# Processing record 236 for goderich with temp 51.89
# Missing field/result, skipping
# Processing record 238 for remontnoye with temp 46.15
# Processing record 239 for rafsanjan with temp 55.06
# Processing record 240 for lae with temp 80.6
# Missing field/result, skipping
# Processing record 242 for willowmore with temp 48.24
# Processing record 243 for raymond terrace with temp 73.35
# Processing record 244 for abalak with temp 86.7
# Processing record 245 for atar with temp 83.05
# Processing record 246 for ballina with temp 50.32
# Processing record 247 for talnakh with temp 24.8
# Processing record 248 for fagernes with temp 37
# Missing field/result, skipping
# Processing record 250 for pingliang with temp 30.79
# Processing record 251 for mount gambier with temp 71.6
# Processing record 252 for namibe with temp 68.81
# Processing record 253 for ierissos with temp 56.43
# Processing record 254 for san quintin with temp 78.66
# Processing record 255 for humberto de campos with temp 77.22
# Missing field/result, skipping
# Processing record 257 for cockburn town with temp 84.2
# Processing record 258 for troyes with temp 55.58
# Processing record 259 for thinadhoo with temp 78.58
# Processing record 260 for honiara with temp 87.8
# Processing record 261 for yaritagua with temp 86
# Processing record 262 for hami with temp 30.42
# Processing record 263 for otane with temp 55.99
# Processing record 264 for dong hoi with temp 77.04
# Processing record 265 for mareeba with temp 74.03
# Missing field/result, skipping
# Processing record 267 for punta alta with temp 79.97
# Processing record 268 for dunnville with temp 53.6
# Processing record 269 for tiksi with temp -0.62
# Processing record 270 for ancud with temp 60.8
# Processing record 271 for evensk with temp 16.34
# Processing record 272 for denpasar with temp 77
# Processing record 273 for surt with temp 66.31
# Processing record 274 for bilibino with temp 5.27
# Processing record 275 for arona with temp 61.32
# Processing record 276 for samarai with temp 78.93
# Processing record 277 for los llanos de aridane with temp 63.91
# Processing record 278 for atambua with temp 83.41
# Missing field/result, skipping
# Processing record 280 for fort nelson with temp 35.6
# Processing record 281 for hasaki with temp 62.29
# Processing record 282 for comodoro rivadavia with temp 50
# Processing record 283 for kurilsk with temp 46.96
# Missing field/result, skipping
# Processing record 285 for kencong with temp 77.25
# Processing record 286 for santa marta with temp 87.8
# Processing record 287 for hay river with temp 35.6
# Processing record 288 for jaromerice nad rokytnou with temp 52.45
# Processing record 289 for raub with temp 72.63
# Processing record 290 for ahipara with temp 70
# Processing record 291 for prince rupert with temp 50
# Processing record 292 for coquimbo with temp 65.03
# Processing record 293 for wasilla with temp 46.83
# Processing record 294 for rio gallegos with temp 53.6
# Processing record 295 for yumen with temp 25.27
# Processing record 296 for muravlenko with temp 26.19
# Processing record 297 for sechura with temp 64.15
# Processing record 298 for sierre with temp 51.87
# Processing record 299 for amapa with temp 84.2
# Processing record 300 for cowra with temp 72
# Processing record 301 for kuching with temp 73.15
# Processing record 302 for basco with temp 63.57
# Processing record 303 for makhinjauri with temp 60.8
# Processing record 304 for sao joao da barra with temp 73.4
# Processing record 305 for banda aceh with temp 73.31
# Processing record 306 for aklavik with temp 21.96
# Processing record 307 for verkh-usugli with temp 15.75
# Processing record 308 for high rock with temp 80.6
# Processing record 309 for suzhou with temp 63.88
# Missing field/result, skipping
# Processing record 311 for udayagiri with temp 67.86
# Processing record 312 for kargasok with temp 32.2
# Processing record 313 for walvis bay with temp 57.69
# Processing record 314 for daru with temp 82.45
# Processing record 315 for yukon with temp 75.22
# Processing record 316 for port-gentil with temp 78.8
# Processing record 317 for toppenish with temp 60.85
# Processing record 318 for campos with temp 53.13
# Processing record 319 for jijiga with temp 58.19
# Processing record 320 for nalut with temp 81.79
# Processing record 321 for amurzet with temp 40.75
# Processing record 322 for shar with temp 72.48
# Processing record 323 for wewak with temp 81.61
# Missing field/result, skipping
# Processing record 325 for cidreira with temp 66.85
# Processing record 326 for nanakuli with temp 84.96
# Missing field/result, skipping
# Processing record 328 for aripuana with temp 75.79
# Processing record 329 for chaman with temp 47.93
# Processing record 330 for auki with temp 76.98
# Processing record 331 for flinders with temp 72.82
# Missing field/result, skipping
# Processing record 333 for mayo with temp 28.4
# Processing record 334 for adrar with temp 68
# Processing record 335 for changping with temp 51.24
# Processing record 336 for narang with temp 66.58
# Processing record 337 for tandalti with temp 84.31
# Processing record 338 for howard springs with temp 82.35
# Processing record 339 for egvekinot with temp 11.52
# Missing field/result, skipping
# Processing record 341 for choszczno with temp 48.74
# Processing record 342 for austin with temp 82.87
# Processing record 343 for verkhnyaya inta with temp 23.9
# Processing record 344 for morondava with temp 75.65
# Processing record 345 for saskylakh with temp 4.35
# Processing record 346 for tombouctou with temp 93.96
# Missing field/result, skipping
# Missing field/result, skipping
# Processing record 349 for palm coast with temp 73.26
# Processing record 350 for itaituba with temp 80.6
# Processing record 351 for mahebourg with temp 71.83
# Processing record 352 for olinda with temp 75.63
# Processing record 353 for hounde with temp 79.43
# Missing field/result, skipping
# Processing record 355 for vestmannaeyjar with temp 30.72
# Processing record 356 for marovoay with temp 78.8
# Processing record 357 for ishigaki with temp 71.6
# Processing record 358 for tessaoua with temp 86.56
# Processing record 359 for jishou with temp 55.53
# Processing record 360 for port augusta with temp 84.2
# Missing field/result, skipping
# Processing record 362 for olovyannaya with temp 21.87
# Processing record 363 for boa vista with temp 84.2
# Processing record 364 for boyolangu with temp 77.25
# Processing record 365 for dalianwan with temp 58.41
# Processing record 366 for pimentel with temp 80.29
# Missing field/result, skipping
# Processing record 368 for faya with temp 60.85
# Processing record 369 for zhuhai with temp 37.4
# Processing record 370 for ostrovnoy with temp 24.03
# Processing record 371 for namatanai with temp 84.24
# Processing record 372 for erenhot with temp 31.33
# Processing record 373 for fonte boa with temp 76.96
# Processing record 374 for verkhoyansk with temp -0.28
# Processing record 375 for nabire with temp 74.66
# Processing record 376 for jieshi with temp 73.99
# Processing record 377 for tessalit with temp 85.03
# Missing field/result, skipping
# Processing record 379 for tyrma with temp 34.27
# Processing record 380 for bonavista with temp 46
# Processing record 381 for ponta do sol with temp 69.04
# Processing record 382 for padron with temp 52.25
# Processing record 383 for jutai with temp 75.88
# Processing record 384 for mujiayingzi with temp 44.31
# Processing record 385 for wageningen with temp 54.9
# Processing record 386 for batagay with temp 0.77
# Processing record 387 for pangnirtung with temp 44.6
# Processing record 388 for ribeirao with temp 78.8
# Missing field/result, skipping
# Processing record 390 for vila franca do campo with temp 69.91
# Processing record 391 for ludvika with temp 46.38
# Processing record 392 for hamilton with temp 53.46
# Processing record 393 for narsaq with temp 30.2
# Processing record 394 for lethem with temp 83.41
# Processing record 395 for tanabe with temp 64.99
# Processing record 396 for najran with temp 68
# Processing record 397 for blagoyevo with temp 28.27
# Missing field/result, skipping
# Missing field/result, skipping
# Processing record 400 for morant bay with temp 80.6
# Processing record 401 for abilene with temp 82.71
# Processing record 402 for weiser with temp 60.4
# Processing record 403 for kruisfontein with temp 52.83
# Processing record 404 for bud with temp 49.44
# Processing record 405 for fairbanks with temp 38.26
# Processing record 406 for weyburn with temp 42.01
# Processing record 407 for mandurah with temp 55.4
# Processing record 408 for nakhon thai with temp 71.71
# Processing record 409 for nantucket with temp 58.35
# Missing field/result, skipping
# Missing field/result, skipping
# Processing record 412 for te anau with temp 41.45
# Processing record 413 for lagoa with temp 59.23
# Processing record 414 for baker city with temp 55.47
# Processing record 415 for orcopampa with temp 39.24
# Processing record 416 for joensuu with temp 33.35
# Processing record 417 for grand gaube with temp 71.8
# Processing record 418 for tynda with temp 25.39
# Missing field/result, skipping
# Processing record 420 for baiyin with temp 28.4
# Processing record 421 for kishi with temp 73.09
# Processing record 422 for anamur with temp 60.8
# Processing record 423 for winnemucca with temp 63
# Processing record 424 for talara with temp 62.6
# Processing record 425 for kamaishi with temp 61.05
# Processing record 426 for buala with temp 83.23
# Processing record 427 for phonhong with temp 75.96
# Processing record 428 for monaghan with temp 51.8
# Processing record 429 for surab with temp 49.95
# Processing record 430 for havoysund with temp 30.2
# Missing field/result, skipping
# Processing record 432 for beloha with temp 71.35
# Processing record 433 for caravelas with temp 73.35
# Processing record 434 for tateyama with temp 61.16
# Missing field/result, skipping
# Processing record 436 for semnan with temp 57.2
# Processing record 437 for ambilobe with temp 77.45
# Processing record 438 for nuuk with temp 30.09
# Processing record 439 for melfort with temp 39.2
# Processing record 440 for basoko with temp 71.15
# Processing record 441 for terrace with temp 44.6
# Processing record 442 for khorixas with temp 67.48
# Processing record 443 for sangueya with temp 76.41
# Processing record 444 for vredendal with temp 55.33
# Processing record 445 for maumere with temp 79.66
# Processing record 446 for bjelovar with temp 47.5
# Processing record 447 for amahai with temp 79.23
# Processing record 448 for jackson with temp 36.75
# Processing record 449 for kumluca with temp 67.44
# Processing record 450 for zlobin with temp 57.52
# Processing record 451 for carahue with temp 60.8
# Processing record 452 for raudeberg with temp 53.53
# Processing record 453 for kudahuvadhoo with temp 81.43
# Processing record 454 for fare with temp 79.93
# Processing record 455 for aligudarz with temp 45.81
# Processing record 456 for miri with temp 75.25
# Processing record 457 for filadelfia with temp 77.47
# Processing record 458 for marsa matruh with temp 66.2
# Processing record 459 for bilma with temp 76.59
# Processing record 460 for olesno with temp 53.89
# Processing record 461 for vysokogornyy with temp 36.95
# Processing record 462 for chuy with temp 56.71
# Processing record 463 for salinas with temp 80.15
# Processing record 464 for mopipi with temp 80.55
# Processing record 465 for kulim with temp 75.09
# Processing record 466 for sicuani with temp 42.57
# Processing record 467 for vorozhba with temp 51.87
# Processing record 468 for wagar with temp 57.02
# Processing record 469 for junction city with temp 62.53
# Missing field/result, skipping
# Processing record 471 for bandar-e lengeh with temp 82.4
# Missing field/result, skipping
# Processing record 473 for barabai with temp 80.53
# Processing record 474 for osakarovka with temp 35.64
# Processing record 475 for kieta with temp 82.89
# Processing record 476 for burnie with temp 63.32
# Processing record 477 for bam with temp 65.17
# Processing record 478 for gubkinskiy with temp 24.96
# Missing field/result, skipping
# Processing record 480 for miranda with temp 76.37
# Missing field/result, skipping
# Processing record 482 for palestine with temp 77.16
# Processing record 483 for lodeynoye pole with temp 41.02
# Processing record 484 for port lincoln with temp 86.74
# Processing record 485 for lebork with temp 45.82
# Processing record 486 for farah with temp 51.04
# Processing record 487 for bontang with temp 79.92
# Processing record 488 for sinnamary with temp 81.43
# Processing record 489 for raha with temp 66.94
# Processing record 490 for ulaangom with temp 21.7
# Processing record 491 for santa catarina de tepehuanes with temp 66.34
# Processing record 492 for kavaratti with temp 82.81
# Processing record 493 for san carlos de bariloche with temp 66.2
# Processing record 494 for sainte-martine with temp 53.53
# Missing field/result, skipping
# Processing record 496 for bone with temp 53.55
# Processing record 497 for muros with temp 52.11
# Processing record 498 for atikokan with temp 31.89
# Processing record 499 for znamenskoye with temp 35.19
# Processing record 500 for serebryansk with temp 26.01
# Processing record 501 for qeshm with temp 77.86
# Missing field/result, skipping
# Processing record 503 for matara with temp 58.39
# Processing record 504 for abdanan with temp 65.44
# Processing record 505 for uzunovo with temp 49.87
# Processing record 506 for batemans bay with temp 66.49
# Processing record 507 for vardo with temp 59.05
# Processing record 508 for iqaluit with temp 33.35
# Missing field/result, skipping
# Processing record 510 for tapes with temp 57.92
# Processing record 511 for shumskiy with temp 27.88
# Processing record 512 for itoman with temp 73.8
# Processing record 513 for tripoli with temp 63.77
# Processing record 514 for ayagoz with temp 28.58
# Processing record 515 for karasuk with temp 35.87
# Processing record 516 for nachalovo with temp 39.07
# Processing record 517 for mezen with temp 30.38
# Processing record 518 for bugiri with temp 64.22
# Processing record 519 for luganville with temp 82.4
# Processing record 520 for lodja with temp 69.8
# Processing record 521 for cedar city with temp 64.76
# Processing record 522 for douglas with temp 45.37
# Processing record 523 for ponte nova with temp 66.34
# Processing record 524 for herat with temp 41.92
# Processing record 525 for foumban with temp 67.3
# Processing record 526 for kalianget with temp 79.99
# Processing record 527 for aitape with temp 82.85
# Processing record 528 for kanniyakumari with temp 78.42
# Processing record 529 for kaeo with temp 66.99
# Processing record 530 for leeton with temp 81.73
# Processing record 531 for camargo with temp 77.11
# Processing record 532 for perth with temp 57.47
# Processing record 533 for chilliwack with temp 54.61
# Processing record 534 for kendal with temp 84.99
# Processing record 535 for vetrisoaia with temp 54.14
# Processing record 536 for miandrivazo with temp 82.53
# Processing record 537 for benicarlo with temp 50.5
# Processing record 538 for lakes entrance with temp 66.99
# Processing record 539 for mnogovershinnyy with temp 34.41
# Processing record 540 for sibolga with temp 72.12
# Processing record 541 for nkayi with temp 73.08
# Processing record 542 for balabac with temp 83.89
# Processing record 543 for hirara with temp 72.52
# Processing record 544 for pasni with temp 80.98
# Processing record 545 for kattivakkam with temp 76.48
# Missing field/result, skipping
# Processing record 547 for sabha with temp 68.04
# Processing record 548 for mantua with temp 60.6
# Processing record 549 for norfolk with temp 62.62
# Processing record 550 for emba with temp 69.35
# Processing record 551 for chudniv with temp 53.26
# Processing record 552 for wanning with temp 50.47
# Processing record 553 for asosa with temp 63.55
# Processing record 554 for belmonte with temp 49.57
# Processing record 555 for vershino-darasunskiy with temp 14.72
# Processing record 556 for sorsk with temp 26.44
# Processing record 557 for kibala with temp 75.2
# Missing field/result, skipping
# Processing record 559 for aden with temp 79.3
# Processing record 560 for aquiraz with temp 80.6
# Processing record 561 for ohara with temp 63.9
# Processing record 562 for tres arroyos with temp 46.02
# Processing record 563 for saint-georges with temp 45.07
# Processing record 564 for zhangye with temp 28.53
# Processing record 565 for sitka with temp 64
# Processing record 566 for aljezur with temp 58.46
# Processing record 567 for lincoln with temp 50.9
# Processing record 568 for darnah with temp 72.14
# Processing record 569 for mayumba with temp 77.94
# Processing record 570 for namtsy with temp 17.6
# Processing record 571 for palmerston with temp 82.35
# Processing record 572 for sambava with temp 70.21
# Processing record 573 for chimoio with temp 73.4
# Processing record 574 for troitskoye with temp 31.37
# Processing record 575 for cap-aux-meules with temp 48.2
# Processing record 576 for meulaboh with temp 79.2
# Processing record 577 for mandalgovi with temp 18.14
# Missing field/result, skipping
# Processing record 579 for bela with temp 79.32
# Processing record 580 for kathu with temp 55.99
# Processing record 581 for san ignacio with temp 71.6
# Processing record 582 for srednekolymsk with temp 2.59
# Processing record 583 for pudozh with temp 40.68
# Processing record 584 for east wenatchee with temp 57.33
# Processing record 585 for aswan with temp 77
# Processing record 586 for ostroleka with temp 46.99
# Processing record 587 for kawalu with temp 74.75
# Processing record 588 for dhemaji with temp 67.01
# Processing record 589 for sidhi with temp 68.47
# Processing record 590 for ngunguru with temp 64
# Processing record 591 for le port with temp 48.81
# Processing record 592 for grevena with temp 52.38
# Processing record 593 for calvinia with temp 48.99
# Processing record 594 for pallisa with temp 64.67
# Missing field/result, skipping
# Processing record 596 for agadir with temp 57.2
# Processing record 597 for abu kamal with temp 73.29
# Processing record 598 for tubuala with temp 80.6
# Processing record 599 for kungurtug with temp 8.78

# %%
print(len(temp))
print(len(lat))
print(len(humidity))
print(len(cloudiness))
print(len(wind_speed))
# Out:
# 543
# 543
# 543
# 543
# 543

# %%
weather_df = pd.DataFrame(list(zip(city_name, lat, temp, humidity, cloudiness, wind_speed)),
                          columns =['City Name', 'Latitude', 'Temperature (F)', 'Humidity', 'Cloudiness', 'Wind Speed (mph)'])
weather_df
# Out:
#               City Name  Latitude  Temperature (F)  Humidity  Cloudiness  \
# 0                Tiznit     29.70            54.32        42           0
# 1               Methoni     36.82            63.82        76           0
# 2                 Pisco    -13.71            67.96        30          62
# 3                  Hovd     63.83            46.04        93          75
# 4           Bandarbeyla      9.49            80.71        68         100
# 5                Bethel     60.79            34.70        86          90
# 6          Constitucion     23.99            77.38        34          75
# 7              Hermanus    -34.42            55.54        86         100
# 8                 Bluff    -23.58            75.88        44          13
# 9        Preobrazheniye     42.90            51.71        46         100
# 10       Port Elizabeth     39.31            60.01        41           1
# 11                 Bara     10.41            75.88        77          42
# 12            Jamestown    -33.21            65.98        19           0
# 13            Marrakesh     31.63            57.20        47           0
# 14              Dudinka     69.41            24.80        85          75
# 15           Port Blair     11.67            77.00       100          20
# 16              Ushuaia    -54.81            57.20        50          40
# 17          Clyde River     70.47            30.20       100          90
# 18              Rikitea    -23.12            70.38        93         100
# 19              Qingdao     36.09            51.80        87           0
# 20             Mpulungu     -8.77            68.56        65          14
# 21                Lulea     65.58            33.80        86         100
# 22             Sisimiut     66.94            25.41        52          82
# 23          New Norfolk    -42.78            59.85        67          66
# 24               Barrow    -38.31            46.02        94          27
# 25                 Hilo     19.71            81.03        52           1
# 26               Castro    -42.48            60.80        59          49
# 27           Nikolskoye     59.70            47.53        81          40
# 28   Santa Cruz del Sur     20.71            85.44        72          14
# 29          Salinopolis     -0.61            82.17        79          49
# ..                  ...       ...              ...       ...         ...
# 513              Darnah     32.77            72.14        77           9
# 514             Mayumba     -3.44            77.94        87         100
# 515              Namtsy     62.72            17.60        85          75
# 516          Palmerston    -12.49            82.35        69          20
# 517             Sambava    -14.27            70.21        97          44
# 518             Chimoio    -19.11            73.40        94          75
# 519          Troitskoye     52.98            31.37        66         100
# 520      Cap-aux-Meules     47.38            48.20        87          90
# 521            Meulaboh      4.14            79.20        81         100
# 522          Mandalgovi     45.76            18.14        50          67
# 523                Bela     26.23            79.32        43           0
# 524               Kathu    -27.70            55.99        29           3
# 525         San Ignacio     -5.15            71.60        88          75
# 526       Srednekolymsk     67.46             2.59        94          96
# 527              Pudozh     61.81            40.68        89         100
# 528      East Wenatchee     47.42            57.33        35           1
# 529               Aswan     24.09            77.00        36           0
# 530           Ostroleka     53.09            46.99        53          20
# 531              Kawalu     -7.38            74.75        61          62
# 532             Dhemaji     27.48            67.01        83         100
# 533               Sidhi     24.41            68.47        59          95
# 534            Ngunguru    -35.62            64.00        54           3
# 535             Le Port     42.87            48.81        91          88
# 536             Grevena     40.09            52.38        50           0
# 537            Calvinia    -31.47            48.99        63          97
# 538             Pallisa      1.17            64.67        96          84
# 539              Agadir     30.42            57.20        76           0
# 540           Abu Kamal     34.45            73.29        36          91
# 541             Tubuala      9.52            80.60        83          40
# 542           Kungurtug     50.60             8.78        74          21
#
#      Wind Speed (mph)
# 0                2.17
# 1                4.70
# 2               19.46
# 3                5.82
# 4                4.25
# 5               19.46
# 6                5.82
# 7               13.69
# 8               12.97
# 9                9.15
# 10               8.05
# 11               4.23
# 12               8.16
# 13               4.70
# 14              24.61
# 15               2.24
# 16               6.93
# 17              19.46
# 18              20.65
# 19               2.24
# 20               3.11
# 21               1.12
# 22              13.24
# 23               5.82
# 24               8.95
# 25               8.05
# 26               5.82
# 27               6.71
# 28              14.79
# 29              16.26
# ..                ...
# 513             11.32
# 514              9.75
# 515              2.24
# 516              6.93
# 517              1.95
# 518              2.75
# 519              9.28
# 520             20.80
# 521              2.71
# 522              4.43
# 523              6.20
# 524              8.03
# 525             21.92
# 526              7.96
# 527              5.59
# 528              6.93
# 529              6.93
# 530              6.49
# 531              2.98
# 532              3.44
# 533              2.26
# 534             15.99
# 535              3.00
# 536              5.82
# 537              1.97
# 538              1.48
# 539              4.25
# 540              3.83
# 541              2.24
# 542              4.36
#
# [543 rows x 6 columns]

# %%
weather_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
temp_plot = weather_df.plot(kind="scatter", x="Latitude", y="Temperature (F)", grid=True, figsize=(8,8),
              title=f"City Latitude vs. Temperature (F) ({now.strftime('%m/%d/%Y')})")

plt.savefig("City_Latitude_v_Temperature.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humidity_plot = weather_df.plot(kind="scatter", x="Latitude", y="Humidity", grid=True, figsize=(8,8),
              title=f"City Latitude vs. Humidity ({now.strftime('%m/%d/%Y')})")

plt.savefig("City_Latitude_v_Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness_plot = weather_df.plot(kind="scatter", x="Latitude", y="Cloudiness", grid=True, figsize=(8,8),
              title=f"City Latitude vs. Cloudiness ({now.strftime('%m/%d/%Y')})")

plt.savefig("City_Latitude_v_Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind_plot = weather_df.plot(kind="scatter", x="Latitude", y="Wind Speed (mph)", grid=True, figsize=(8,8),
              title=f"City Latitude vs. Wind Speed (mph) ({now.strftime('%m/%d/%Y')})")

plt.savefig("City_Latitude_v_Wind Speed.png")

plt.show()

# %% [markdown]
# Observations:
#
# 1. As expected temperatures do increase as you get closer to the equator, however they drop off much faster in the positive latitudes versus the negative latititudes.
#
# 2. Locations in the northern hemisphere have higher humidity than locations in the southern hemisphere. These higher levels of humidity are likely due to the lower temperatures. (Ref: https://sciencing.com/temperature-ampamp-humidity-related-7245642.html)
#
# 3. There is significantly less land mass in the southern hemisphere which in turn causes there to be more datapoints in for cities in the northern hemisphere scewing the data. That being said it appears from the plot of cloudiness that there is a fairly even spread between both northern and southern hemispheres with no real massing or thinning of clouds near the equator.
